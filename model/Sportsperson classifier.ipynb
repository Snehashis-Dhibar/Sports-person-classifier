# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/anand.jpg')
img.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (500, 500)

# %%
gray
# Out:
# array([[ 67,  67,  67, ..., 135, 134, 134],
#        [ 67,  67,  67, ..., 133, 134, 134],
#        [ 68,  68,  68, ..., 134, 134, 134],
#        ...,
#        [ 22,  21,  20, ...,  28,  30,  33],
#        [ 23,  22,  20, ...,  29,  30,  32],
#        [ 24,  23,  21, ...,  30,  29,  31]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')
eye_spect_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye_tree_eyeglasses.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[115,  77, 275, 275]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (115, 77, 275, 275)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(face_img)

# %%
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_spect_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (275, 275, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    try:
        img = cv2.imread(image_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                return roi_color
    except:
        return None

# %%
original_image = cv2.imread('./test_images/91b37-16741295618495-1920.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/91b37-16741295618495-1920.jpg')
plt.imshow(cropped_image)

# %%
original_image = cv2.imread('./test_images/15federer-photos-slide-V9RG-mediumSquareAt3X.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/15federer-photos-slide-V9RG-mediumSquareAt3X.jpg')
cropped_image

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/virat kohli',
#  './dataset/roger federer',
#  './dataset/lionel messi',
#  './dataset/tiger woods',
#  './dataset/vishwanathan anand']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
img_dirs
# Out:
# ['./dataset/virat kohli',
#  './dataset/roger federer',
#  './dataset/lionel messi',
#  './dataset/tiger woods',
#  './dataset/vishwanathan anand']

# %%
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
# Out:
# virat kohli
# roger federer
# lionel messi
# tiger woods
# vishwanathan anand

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# virat kohli
# Generating cropped images in folder:  ./dataset/cropped/virat kohli
# libpng warning: iCCP: known incorrect sRGB profile
# roger federer
# Generating cropped images in folder:  ./dataset/cropped/roger federer
# lionel messi
# Generating cropped images in folder:  ./dataset/cropped/lionel messi
# imread_('./dataset/lionel messi/01gx87zcm94ny6bf75k2.jpg'): can't read data: OpenCV(4.8.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/grfmt_jpeg2000_openjpeg.cpp:641: error: (-2:Unspecified error) in function 'virtual bool cv::detail::Jpeg2KOpjDecoderBase::readData(cv::Mat &)'
# > OpenJPEG2000: tiles are not supported (expected: '(int)comp.dx == 1'), where
# >     '(int)comp.dx' is 2
# > must be equal to
# >     '1' is 1
#
# libpng warning: iCCP: known incorrect sRGB profile
# tiger woods
# Generating cropped images in folder:  ./dataset/cropped/tiger woods
# vishwanathan anand
# Generating cropped images in folder:  ./dataset/cropped/vishwanathan anand

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'virat kohli': ['./dataset/cropped/virat kohli/virat kohli3.png',
#   './dataset/cropped/virat kohli/virat kohli76.png',
#   './dataset/cropped/virat kohli/virat kohli62.png',
#   './dataset/cropped/virat kohli/virat kohli63.png',
#   './dataset/cropped/virat kohli/virat kohli77.png',
#   './dataset/cropped/virat kohli/virat kohli2.png',
#   './dataset/cropped/virat kohli/virat kohli61.png',
#   './dataset/cropped/virat kohli/virat kohli75.png',
#   './dataset/cropped/virat kohli/virat kohli49.png',
#   './dataset/cropped/virat kohli/virat kohli48.png',
#   './dataset/cropped/virat kohli/virat kohli74.png',
#   './dataset/cropped/virat kohli/virat kohli60.png',
#   './dataset/cropped/virat kohli/virat kohli1.png',
#   './dataset/cropped/virat kohli/virat kohli5.png',
#   './dataset/cropped/virat kohli/virat kohli58.png',
#   './dataset/cropped/virat kohli/virat kohli64.png',
#   './dataset/cropped/virat kohli/virat kohli70.png',
#   './dataset/cropped/virat kohli/.DS_Store',
#   './dataset/cropped/virat kohli/virat kohli71.png',
#   './dataset/cropped/virat kohli/virat kohli65.png',
#   './dataset/cropped/virat kohli/virat kohli59.png',
#   './dataset/cropped/virat kohli/virat kohli4.png',
#   './dataset/cropped/virat kohli/virat kohli6.png',
#   './dataset/cropped/virat kohli/virat kohli73.png',
#   './dataset/cropped/virat kohli/virat kohli67.png',
#   './dataset/cropped/virat kohli/virat kohli66.png',
#   './dataset/cropped/virat kohli/virat kohli72.png',
#   './dataset/cropped/virat kohli/virat kohli7.png',
#   './dataset/cropped/virat kohli/virat kohli15.png',
#   './dataset/cropped/virat kohli/virat kohli29.png',
#   './dataset/cropped/virat kohli/virat kohli28.png',
#   './dataset/cropped/virat kohli/virat kohli14.png',
#   './dataset/cropped/virat kohli/virat kohli16.png',
#   './dataset/cropped/virat kohli/virat kohli17.png',
#   './dataset/cropped/virat kohli/virat kohli13.png',
#   './dataset/cropped/virat kohli/virat kohli12.png',
#   './dataset/cropped/virat kohli/virat kohli10.png',
#   './dataset/cropped/virat kohli/virat kohli11.png',
#   './dataset/cropped/virat kohli/virat kohli34.png',
#   './dataset/cropped/virat kohli/virat kohli20.png',
#   './dataset/cropped/virat kohli/virat kohli21.png',
#   './dataset/cropped/virat kohli/virat kohli35.png',
#   './dataset/cropped/virat kohli/virat kohli23.png',
#   './dataset/cropped/virat kohli/virat kohli37.png',
#   './dataset/cropped/virat kohli/virat kohli36.png',
#   './dataset/cropped/virat kohli/virat kohli26.png',
#   './dataset/cropped/virat kohli/virat kohli32.png',
#   './dataset/cropped/virat kohli/virat kohli33.png',
#   './dataset/cropped/virat kohli/virat kohli27.png',
#   './dataset/cropped/virat kohli/virat kohli19.png',
#   './dataset/cropped/virat kohli/virat kohli31.png',
#   './dataset/cropped/virat kohli/virat kohli25.png',
#   './dataset/cropped/virat kohli/virat kohli24.png',
#   './dataset/cropped/virat kohli/virat kohli30.png',
#   './dataset/cropped/virat kohli/virat kohli18.png',
#   './dataset/cropped/virat kohli/virat kohli57.png',
#   './dataset/cropped/virat kohli/virat kohli43.png',
#   './dataset/cropped/virat kohli/virat kohli42.png',
#   './dataset/cropped/virat kohli/virat kohli56.png',
#   './dataset/cropped/virat kohli/virat kohli9.png',
#   './dataset/cropped/virat kohli/virat kohli40.png',
#   './dataset/cropped/virat kohli/virat kohli54.png',
#   './dataset/cropped/virat kohli/virat kohli68.png',
#   './dataset/cropped/virat kohli/virat kohli69.png',
#   './dataset/cropped/virat kohli/virat kohli55.png',
#   './dataset/cropped/virat kohli/virat kohli41.png',
#   './dataset/cropped/virat kohli/virat kohli8.png',
#   './dataset/cropped/virat kohli/virat kohli45.png',
#   './dataset/cropped/virat kohli/virat kohli51.png',
#   './dataset/cropped/virat kohli/virat kohli50.png',
#   './dataset/cropped/virat kohli/virat kohli44.png',
#   './dataset/cropped/virat kohli/virat kohli78.png',
#   './dataset/cropped/virat kohli/virat kohli52.png',
#   './dataset/cropped/virat kohli/virat kohli46.png',
#   './dataset/cropped/virat kohli/virat kohli47.png',
#   './dataset/cropped/virat kohli/virat kohli53.png'],
#  'roger federer': ['./dataset/cropped/roger federer/roger federer23.png',
#   './dataset/cropped/roger federer/roger federer20.png',
#   './dataset/cropped/roger federer/roger federer24.png',
#   './dataset/cropped/roger federer/roger federer18.png',
#   './dataset/cropped/roger federer/.DS_Store',
#   './dataset/cropped/roger federer/roger federer19.png',
#   './dataset/cropped/roger federer/roger federer25.png',
#   './dataset/cropped/roger federer/roger federer27.png',
#   './dataset/cropped/roger federer/roger federer26.png',
#   './dataset/cropped/roger federer/roger federer1.png',
#   './dataset/cropped/roger federer/roger federer3.png',
#   './dataset/cropped/roger federer/roger federer2.png',
#   './dataset/cropped/roger federer/roger federer6.png',
#   './dataset/cropped/roger federer/roger federer7.png',
#   './dataset/cropped/roger federer/roger federer5.png',
#   './dataset/cropped/roger federer/roger federer4.png',
#   './dataset/cropped/roger federer/roger federer9.png',
#   './dataset/cropped/roger federer/roger federer8.png',
#   './dataset/cropped/roger federer/roger federer16.png',
#   './dataset/cropped/roger federer/roger federer28.png',
#   './dataset/cropped/roger federer/roger federer14.png',
#   './dataset/cropped/roger federer/roger federer15.png',
#   './dataset/cropped/roger federer/roger federer10.png',
#   './dataset/cropped/roger federer/roger federer13.png'],
#  'lionel messi': ['./dataset/cropped/lionel messi/lionel messi43.png',
#   './dataset/cropped/lionel messi/lionel messi57.png',
#   './dataset/cropped/lionel messi/lionel messi80.png',
#   './dataset/cropped/lionel messi/lionel messi81.png',
#   './dataset/cropped/lionel messi/lionel messi42.png',
#   './dataset/cropped/lionel messi/lionel messi54.png',
#   './dataset/cropped/lionel messi/lionel messi40.png',
#   './dataset/cropped/lionel messi/lionel messi82.png',
#   './dataset/cropped/lionel messi/lionel messi69.png',
#   './dataset/cropped/lionel messi/lionel messi41.png',
#   './dataset/cropped/lionel messi/lionel messi79.png',
#   './dataset/cropped/lionel messi/lionel messi45.png',
#   './dataset/cropped/lionel messi/.DS_Store',
#   './dataset/cropped/lionel messi/lionel messi44.png',
#   './dataset/cropped/lionel messi/lionel messi50.png',
#   './dataset/cropped/lionel messi/lionel messi78.png',
#   './dataset/cropped/lionel messi/lionel messi46.png',
#   './dataset/cropped/lionel messi/lionel messi52.png',
#   './dataset/cropped/lionel messi/lionel messi53.png',
#   './dataset/cropped/lionel messi/lionel messi47.png',
#   './dataset/cropped/lionel messi/lionel messi20.png',
#   './dataset/cropped/lionel messi/lionel messi34.png',
#   './dataset/cropped/lionel messi/lionel messi21.png',
#   './dataset/cropped/lionel messi/lionel messi37.png',
#   './dataset/cropped/lionel messi/lionel messi23.png',
#   './dataset/cropped/lionel messi/lionel messi8.png',
#   './dataset/cropped/lionel messi/lionel messi9.png',
#   './dataset/cropped/lionel messi/lionel messi22.png',
#   './dataset/cropped/lionel messi/lionel messi36.png',
#   './dataset/cropped/lionel messi/lionel messi32.png',
#   './dataset/cropped/lionel messi/lionel messi26.png',
#   './dataset/cropped/lionel messi/lionel messi27.png',
#   './dataset/cropped/lionel messi/lionel messi33.png',
#   './dataset/cropped/lionel messi/lionel messi19.png',
#   './dataset/cropped/lionel messi/lionel messi25.png',
#   './dataset/cropped/lionel messi/lionel messi31.png',
#   './dataset/cropped/lionel messi/lionel messi30.png',
#   './dataset/cropped/lionel messi/lionel messi24.png',
#   './dataset/cropped/lionel messi/lionel messi18.png',
#   './dataset/cropped/lionel messi/lionel messi29.png',
#   './dataset/cropped/lionel messi/lionel messi2.png',
#   './dataset/cropped/lionel messi/lionel messi3.png',
#   './dataset/cropped/lionel messi/lionel messi28.png',
#   './dataset/cropped/lionel messi/lionel messi14.png',
#   './dataset/cropped/lionel messi/lionel messi16.png',
#   './dataset/cropped/lionel messi/lionel messi1.png',
#   './dataset/cropped/lionel messi/lionel messi17.png',
#   './dataset/cropped/lionel messi/lionel messi13.png',
#   './dataset/cropped/lionel messi/lionel messi4.png',
#   './dataset/cropped/lionel messi/lionel messi5.png',
#   './dataset/cropped/lionel messi/lionel messi12.png',
#   './dataset/cropped/lionel messi/lionel messi38.png',
#   './dataset/cropped/lionel messi/lionel messi10.png',
#   './dataset/cropped/lionel messi/lionel messi7.png',
#   './dataset/cropped/lionel messi/lionel messi6.png',
#   './dataset/cropped/lionel messi/lionel messi11.png',
#   './dataset/cropped/lionel messi/lionel messi39.png',
#   './dataset/cropped/lionel messi/lionel messi62.png',
#   './dataset/cropped/lionel messi/lionel messi76.png',
#   './dataset/cropped/lionel messi/lionel messi77.png',
#   './dataset/cropped/lionel messi/lionel messi63.png',
#   './dataset/cropped/lionel messi/lionel messi75.png',
#   './dataset/cropped/lionel messi/lionel messi61.png',
#   './dataset/cropped/lionel messi/lionel messi49.png',
#   './dataset/cropped/lionel messi/lionel messi48.png',
#   './dataset/cropped/lionel messi/lionel messi60.png',
#   './dataset/cropped/lionel messi/lionel messi74.png',
#   './dataset/cropped/lionel messi/lionel messi70.png',
#   './dataset/cropped/lionel messi/lionel messi64.png',
#   './dataset/cropped/lionel messi/lionel messi65.png',
#   './dataset/cropped/lionel messi/lionel messi71.png',
#   './dataset/cropped/lionel messi/lionel messi59.png',
#   './dataset/cropped/lionel messi/lionel messi67.png',
#   './dataset/cropped/lionel messi/lionel messi73.png',
#   './dataset/cropped/lionel messi/lionel messi72.png',
#   './dataset/cropped/lionel messi/lionel messi66.png'],
#  'tiger woods': ['./dataset/cropped/tiger woods/tiger woods14.png',
#   './dataset/cropped/tiger woods/tiger woods4.png',
#   './dataset/cropped/tiger woods/tiger woods5.png',
#   './dataset/cropped/tiger woods/tiger woods15.png',
#   './dataset/cropped/tiger woods/tiger woods6.png',
#   './dataset/cropped/tiger woods/tiger woods16.png',
#   './dataset/cropped/tiger woods/tiger woods12.png',
#   './dataset/cropped/tiger woods/.DS_Store',
#   './dataset/cropped/tiger woods/tiger woods2.png',
#   './dataset/cropped/tiger woods/tiger woods13.png',
#   './dataset/cropped/tiger woods/tiger woods11.png',
#   './dataset/cropped/tiger woods/tiger woods1.png',
#   './dataset/cropped/tiger woods/tiger woods10.png',
#   './dataset/cropped/tiger woods/tiger woods18.png',
#   './dataset/cropped/tiger woods/tiger woods8.png',
#   './dataset/cropped/tiger woods/tiger woods9.png',
#   './dataset/cropped/tiger woods/tiger woods19.png'],
#  'vishwanathan anand': ['./dataset/cropped/vishwanathan anand/vishwanathan anand16.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand17.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand2.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand29.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand15.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand14.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand28.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand3.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand7.png',
#   './dataset/cropped/vishwanathan anand/.DS_Store',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand10.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand38.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand11.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand6.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand4.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand12.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand49.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand75.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand61.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand60.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand48.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand62.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand76.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand77.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand63.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand88.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand67.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand73.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand72.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand64.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand58.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand68.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand54.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand40.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand55.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand69.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand82.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand80.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand43.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand57.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand56.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand81.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand85.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand46.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand52.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand90.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand84.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand86.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand45.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand79.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand78.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand44.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand87.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand8.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand37.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand23.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand22.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand36.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand9.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand20.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand34.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand35.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand21.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand25.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand19.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand18.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand30.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand32.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand26.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand27.png',
#   './dataset/cropped/vishwanathan anand/vishwanathan anand33.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'virat kohli': 0,
#  'roger federer': 1,
#  'lionel messi': 2,
#  'tiger woods': 3,
#  'vishwanathan anand': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (259, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.9076923076923077

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        17
#            1       1.00      0.33      0.50         3
#            2       0.95      0.86      0.90        21
#            3       1.00      0.83      0.91         6
#            4       0.82      1.00      0.90        18
#
#     accuracy                           0.91        65
#    macro avg       0.94      0.80      0.84        65
# weighted avg       0.92      0.91      0.90        65

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.844669
# 1        random_forest    0.737112
# 2  logistic_regression    0.813765
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9230769230769231

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8615384615384616

# %%
best_clf2 = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm2 = confusion_matrix(y_test, best_clf2.predict(X_test))
cm2
# Out:
# array([[17,  0,  0,  0,  0],
#        [ 0,  1,  1,  0,  1],
#        [ 0,  0, 19,  0,  2],
#        [ 0,  0,  0,  5,  1],
#        [ 0,  0,  0,  0, 18]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm2, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[15,  0,  0,  2,  0],
#        [ 0,  2,  0,  0,  1],
#        [ 0,  1, 18,  2,  0],
#        [ 0,  0,  0,  6,  0],
#        [ 0,  1,  0,  2, 15]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'virat kohli': 0,
#  'roger federer': 1,
#  'lionel messi': 2,
#  'tiger woods': 3,
#  'vishwanathan anand': 4}

# %%
# !pip install joblib
import joblib 
joblib.dump(best_clf2, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in /Users/snehashisdhibar/anaconda3/lib/python3.11/site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
